# %%
# Import the necessary library
import pandas as pd

# %%
df = pd.read_csv('pnw_earthquake_data_final.csv')

# %%
df.head()
# Out:
#                                time   latitude   longitude   depth   mag  \
# 0  1983-12-31 22:39:39.800000+00:00  37.549833 -118.864500   2.914  3.90
# 1  1983-12-30 16:23:53.270000+00:00  46.349500 -122.412167   6.923  2.60
# 2  1983-12-29 10:46:05.220000+00:00  46.262500 -122.647833  13.450  3.00
# 3  1983-12-28 23:58:07.730000+00:00  38.812000 -122.809500   2.170  2.51
# 4  1983-12-28 08:20:23.370000+00:00  37.476333 -118.805500   7.215  3.04
#
#   magType   nst    gap     dmin   rms  ...  \
# 0      ml  25.0   60.0  0.04144  0.06  ...
# 1      md  31.0   53.0      NaN  0.22  ...
# 2      md  33.0  117.0      NaN  0.21  ...
# 3      md  29.0   48.0  0.01261  0.08  ...
# 4      md  23.0  127.0  0.06757  0.04  ...
#
#                                    place        type horizontalError  \
# 0   13 km W of Aspen Springs, California  earthquake           0.320
# 1     20 km SSE of Mossyrock, Washington  earthquake           0.590
# ...

# %%
df.info()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32230 entries, 0 to 32229
# Data columns (total 23 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   time             31832 non-null  object
#  1   latitude         32230 non-null  float64
#  2   longitude        32230 non-null  float64
#  3   depth            32225 non-null  float64
#  4   mag              32230 non-null  float64
#  5   magType          32228 non-null  object
#  6   nst              31426 non-null  float64
#  7   gap              31646 non-null  float64
#  8   dmin             28289 non-null  float64
#  9   rms              31663 non-null  float64
#  10  net              32230 non-null  object
#  11  id               32230 non-null  object
#  12  updated          32230 non-null  object
#  13  place            32230 non-null  object
#  14  type             32230 non-null  object
#  15  horizontalError  30526 non-null  float64
# ...
